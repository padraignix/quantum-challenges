# %% [markdown]
# ![Challenges_Blog Image_Feature.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 0: Welcome and Hello World

# %% [markdown]
# # Table of Contents
#
# * [Welcome to the 2024 IBM Quantum Challenge](#welcome)
#   * [Lab 0 overview](#overview)
#   * [Install Qiskit](#install)
#   * [Configure your Challenge environment](#configure)
# * [Generate a two-qubit Bell state using Qiskit patterns](#generate)
#   * [Step 1: Map circuits and operators](#step-1)
#     * [Exercise 1](#ex-1)
#     * [The grader cell](#grader)
#   * [Step 2: Optimize the circuit](#step-2)
#   * [Step 3: Execute the circuit](#step-3)
#   * [Step 4: Post-process the results](#step-4)
#     * [Exercise 2](#ex-2)
# * [Congratulations](#congrats)

# %% [markdown]
# ## Welcome to the 2024 IBM Quantum Challenge! <a name="welcome"></a>
#
# We're thrilled that you're joining us for this event. This year's Quantum Challenge is designed to highlight **Qiskit SDK v1.0**, which IBM released earlier this year. Returning participants may notice some exciting differences between this year's Challenge and its predecessors. But while the setting may be different, the overall structure remains the same. As always, this year's challenge consists of a series of "labs" — Jupyter Notebooks specially designed to get you working through problems just like a real quantum computational scientist.
#
# Each of these lab notebooks focuses on a different topic and build upon the previous learning. This first lab is meant for anyone to complete, even beginners, but later labs are much more difficult. This is, after all, a *Challenge*. Most participants will need to do some outside research or use a bit of trial-and-error to finish the code challenges presented in the more advanced labs. Don't give up! We know you can do it.
#
# In each lab notebook, you will find plenty of links to documentation, tutorials, and other helpful resources you might need to solve that particular problem. You can also find most of these resources on IBM's new home for quantum education: [IBM Quantum Learning](https://learning.quantum.ibm.com/). We hope you'll take some time to explore it. We are especially proud of the series of courses featured there.
#
# If you ever get lost, remember you can find the home of this year's Quantum Challenge [here](https://challenges.quantum.ibm.com/2024). Each time you complete a Challenge lab, you'll find your progress reflected there.

# %% [markdown]
# ## Lab 0 overview <a name="overview"></a>
#
# In this lab, we'll focus on teaching you how to use these challenge notebooks, how to grade your work, and how to manage the general flow of setting up, running, and evaluating the results of your quantum code.
#
# To complete this and the other labs, you'll need to know a little bit about the Python programming language. Each lab contains a mixture of tutorial content, pre-written code blocks, and challenge code blocks that require you to fill in your own [Qiskit code](https://www.ibm.com/quantum/qiskit). To complete an exercise, you'll need to type the required code underneath each line that has the `## Write your code below here ##` comment.
#
# It's important to note that you should **run every code cell**, even if you didn't write any new code there. This ensures that when you submit your answers later on, everything is up to date.

# %% [markdown]
# ## Install Qiskit <a name="install"></a>
#
# Where are you reading this sentence right now? Are you using a local coding environment and seeing this inside a Jupyter notebook that you opened? Or maybe you're using a cloud-based tool like Google Colab or qBriad and you're reading this through your browser? Are you the type of person who likes to navigate through the command line? Or would you prefer the cozy comfort of your favorite IDE?
#
# No matter where this is reaching you, one thing remains true. You'll need to make sure you have Qiskit installed to successfully complete the IBM Quantum Challenge.
#
# If you are relatively new to using Qiskit, or need a reminder on how to install things locally, [watch this video to walk you through every step of the process](https://www.youtube.com/watch?v=dZWz4Gs_BuI), or run the next cell to embed the video here in the notebook.

# %%
### Run this cell to watch the Qiskit Install video

from IPython.display import HTML
HTML('<iframe width="960" height="540" src="https://www.youtube.com/embed/dZWz4Gs_BuI" title="How to Install Qiskit" frameborder="0" allow="accelerometer; autoplay; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# If you are choosing to open these notebooks in a **cloud-based environment** ([like Google Colab](https://colab.research.google.com/)), you still need to install Qiskit.
#
# We have already provided the installs for you in the next cell. Simply run it and wait until it finishes.

# %%
### Use this cell to install Qiskit and the other needed packages.
### If you're using a cloud-based Jupyter Notebook, just run the cell

### If you are running your code locally or in a command line,
### you should remove the '!' at the beginning of each line

# !pip install qiskit[visualization]
# !pip install qiskit_aer
# !pip install qiskit_ibm_runtime
# !pip install matplotlib
# !pip install pylatexenc
# !pip install git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git

# %% [markdown]
# Nice job! Now, let's test to make sure everything is working properly. We've provided some very basic Qiskit code for you in the following cell. This code will create a quantum circuit, apply a single gate, and then draw that circuit. Run the cell below to make sure your system is set up properly.

# %%
from qiskit import QuantumCircuit

# Create a new circuit with a single qubit
qc = QuantumCircuit(1)

# Add a Not gate to qubit 0
qc.x(0)

# Return a drawing of the circuit using MatPlotLib ("mpl"). This is the
# last line of the cell, so the drawing appears in the cell output.
qc.draw("mpl")

# %% [markdown]
# Did everything work as expected? Congratulations! You're ready to move on to the next task.
#
# Not working quite yet? Let's check your installs and versions to make sure everything is what it should be. Just remove the single `#` in front of the code that corresponds to your operating system.

# %%
### CHECK QISKIT VERSION (On Mac)
# !pip list | grep qiskit

### CHECK QISKIT VERSION (on PC)
# !pip list | find "qiskit"

# %% [markdown]
# You should have Qiskit version 1.0.2 (or later) installed. If you see a version lower than that, you'll need to restart your kernel and reinstall the latest version of Qiskit.
#
# While we're here, let's double-check that the other dependencies are correctly installed. *Is this really necessary after installing these packages just a few minutes ago?* Probably not. But in the wild world of Jupyter Notebooks, understanding how to diagnose a problem is an invaluable asset. Checking to make sure all your packages are installed in the way that you expect is one of the first bug-fixing steps to take, and sometimes solves your entire problem right there.
#
# Remember, if you need to reinstall any packages, it's best to restart your kernel (or runtime) first.

# %%
### CHECK OTHER DEPENDENCIES
# !pip show pylatexenc matplotlib

# %% [markdown]
# Other common issues could be solved by the following:
#
#
# *   If you aren't seeing any output, make sure you've run each code cell.
# *   Try restarting your kernel. How you do this varies by the environment you're using. In Google Colab you do this by clicking "runtime" in the menu bar, then "restart session."
#
#
# If you're still running into problems, check out this [Coding with Qiskit](https://www.youtube.com/watch?v=dZWz4Gs_BuI) video for additional tips, or explore [the documentation](https://docs.quantum.ibm.com/start/install) for help.

# %% [markdown]
# ## Configure your challenge environment <a name="configure"></a>
#
# There are just a few last things to set up before you're ready to begin.
#
# You already installed the Quantum Challenge Grader above. This is necessary to properly check your answers. In the code cell below, we check to see if you have the most up-to-date version installed.

# %%
# !pip show qc_grader

#qc-grader should be 0.18.4 (or higher)

# %% [markdown]
# Crucially, you also need to **store your API token** to track your progress. If you do not properly store your API token, none of your work here will sync back to the Challenge portal.

# %% [markdown]
# ![Screenshot 2024-05-21 at 8.44.51 PM.png](data:image/png;base64,...)

# %% [markdown]
# This is so important that we're also going to make it a step by step list.
#
#
#
# 1.   Navigate to the [IBM Quantum Platform](https://quantum.ibm.com/)
# 2.   Make sure you log in using the same email you registered for this event with
# 3.   In the top right corner, click and copy your API token (pictured above)
# 4.   Paste the API token in the code cell below, directly following `%set_env QXToken=`
# 5.   Make sure there is no space between the equal sign and your token

# %%
### PLACE YOUR API TOKEN BELOW

# %set_env QXToken=#Your_API_Token_goes_here


### Make sure there is no space inbetween the '=' and the beginning of your token

# %% [markdown]
# # Generate a two-qubit Bell state using Qiskit patterns <a name="generate"></a>
#
# In this lab we follow along with the [third episode of Coding with Qiskit 1.x](https://www.youtube.com/watch?v=93-zLTppFZw&list=PLOFEBzvs-VvrgHZt3exM_NNiNKtZlHvZi&index=3). We've added a couple coding challenges to make sure you're grasping the basics. This is the first lab in the IBM Quantum Challenge, so you can expect it to be easy. Solving future labs will require much more thought and research.
#
# Our goal in this lab is to generate a two-qubit Bell state using the approach provided by **Qiskit patterns.**
#
# A Qiskit pattern is a four step workflow for setting up, running, and getting results from a quantum computer. This is the workflow designed to help you use utility-scale quantum computers. It works as follows:
#
# 1. Map circuits and operators
# 2. Optimize the circuit
# 3. Execute the circuit
# 4. Post-process the results

# %% [markdown]
# ##  Step 1: Map circuits and operators <a name="step-1"></a>

# %% [markdown]
# Mapping your problem to circuits and operators is fairly easy when you're only dealing with a handful of qubits, but can get more difficult as you scale up. To start, we will construct a Bell state. This is a classic (*or should I say, "quantum"*) example that showcases entanglement between two qubits.
#
# First we apply a Hadamard gate to qubit 0, placing it in a superposition. Then we apply a CNOT gate between qubits 0 and 1. The CNOT effectively entangles our qubits, meaning that when we measure the output of this circuit we should expect to see a connection between both qubits.
#
# If that made sense to you, nice job, you're ready to go. However, if that went over your head, the Challenge will be quite difficult for you. Instead, you may want to take this time to review the course on [Quantum Information and Computation](https://learning.quantum.ibm.com/course/basics-of-quantum-information/quantum-circuits).

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import EstimatorV2 as Estimator

# Create a new circuit with two qubits
qc = QuantumCircuit(2)

# Add a Hadamard gate to qubit 0
qc.h(0)

# Perform a CNOT gate on qubit 1, controlled by qubit 0
qc.cx(0, 1)

# Return a drawing of the circuit using MatPlotLib ("mpl"). This is the
# last line of the cell, so the drawing appears in the cell output.
# Remove the "mpl" argument to get a text drawing.
qc.draw("mpl")

# %% [markdown]
# We also want to be able to visualize that our circuit does what we expect it to do. To accomplish this, let's set up some **operators**.
#
# - *Don't have any clue what an operator or a gate is? [Take a quick detour and learn more here](https://docs.quantum.ibm.com/build/specify-observables-pauli#specify-observables-in-the-pauli-basis)*
#
# Here we create some one-qubit and two-qubit operators, and later we will check their expectation values to make sure our circuit is working properly. Because we've created an entangled Bell state, we should expect that our *single-qubit operators* have an expectation value of 0. Similarly, we should expect the *two-qubit operators* to come back with some non-zero (hopefully close to 1) expectation value.
#
# How do we do this? We simply use a combination of `X`, `Z`, and Identity (`I`) operators.
#
# * Applying an `I` gate to a qubit is the same as doing nothing to a qubit. We use a combination of `X`/`Z` and `I` to make our single-qubit operators
# * We only have a couple of two-qubit operators to make, `XX` and `YY`. We use a combination of `X` or `Z` gates to make each one, respectfully
#
# Later on in this lab, you will graph the expectation values for all of these operators to check our results.

# %% [markdown]
# ### Exercise 1 <a name="ex-1"></a>
# <div class="alert alert-block alert-success">
#
# Hey, look as us. Who would have thought — we made it to our first Challenge exercise!
#
# In this first exercise, you should complete the list of operators. We have provided three for you already: the `ZZ`, `ZI`, and `IX` observables. We've also written comments in the code explaining what each observable is looking for.
#
# **Following the same approach, your task is to create the last three operators:** `IZ`, `XX`, and `XI`
#
# </div>

# %%
from qiskit.quantum_info import Pauli

# the ZZ applies a Z operator on qubit 0, and a Z operator on qubit 1
ZZ = Pauli('ZZ')

# the ZI applies a Z operator on qubit 0, and an Identity operator on qubit 1
ZI = Pauli('ZI')

# the IX applies an Identity operator on qubit 0, and an X operator on qubit 1
IX = Pauli('IX')



### Write your code below here ###
### Follow the same naming convention we used above



## Don't change any code past this line, but remember to run the cell.

observables = [IZ, IX, ZI, XI, ZZ, XX]

# %% [markdown]
# ### The grader cell <a name="grader"></a>
#
# Every exercise you complete in the IBM Quantum Challenge is followed by a grader cell. The grader takes the code from the exercise cell you just completed, and passes it to a hidden auto-grader. Sometimes it will simply tell you "right" or "wrong." However, for more complex exercises, we include hints or suggestions. Each grader cell is unique to each exercise. Make sure you run all the code cells prior to running the grader.
#
# **You do not need to add any code into the grader cell. Simply run the grader cell to submit your answer.**
#
# Try it out below to see if you completed Exercise 1 properly.

# %%
# Submit your answer using following code

from qc_grader.challenges.iqc_2024 import grade_lab0_ex1

grade_lab0_ex1(observables)

# %% [markdown]
# If you received an error, here are some potential fixes:
#
#
#
# *   **Error:** `Failed: 401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken`
#   *   **Solution:** Return to the *Configure your challenge environment* section and properly store your API token
# *   **Error:** `NameError: name 'observables' is not defined`
#   *   **Solution:** You need to run the code cell in Exercise 1 prior to running the Grader cell
# *   **Error:** ` Failed: Unable to access service (Forbidden)`
#   *   **Solution:** You did not properly install your grader package. Restart your kernel and run all above code cells before returning here
#
#
#
# If you have a different error, head over to the IBM Quantum Challenge Discord server (link in your email) and ask there.

# %% [markdown]
# ## Step 2: Optimize the circuit <a name="step-2"></a>

# %% [markdown]
# A Qiskit pattern is the best framework for working with a quantum computer at *utility scale* — the point where quantum computations are made up of 100 qubits or more. However, in this intro section, we're only using two qubits. So, that means we do not need to do any work here to optimize the circuit.
#
# Optimizing the circuit is an opportunity for advanced transpilation. The transpiling process is where we do things like shuffling our gates to make execution more parallel across all qubits — just one example of many. You'll learn more about this process in later labs. For now, you can move on to the next step of the pattern.

# %% [markdown]
# ## Step 3: Execute the circuit <a name="step-3"></a>

# %% [markdown]
# Time to run the circuit.
#
# In this next cell, you might notice something new. We are going to run the circuit using Qiskit Runtime.
#
# The next lab of the IBM Quantum Challenge covers Qiskit Runtime and the primitives in much greater detail. We won't talk about it too much in this lab other than to say that Qiskit Runtime gives us the easiest means of running our circuit.
#
# When you run the cell below, you should see a large amount of text show up as the cell's output. This tells you all the raw information you need to know about the circuit, how it was run, how many times it ran (i.e., how many "shots"), and more.
#
# If you're the curious type, you can explore the full output. If you're more of a visual learner, feel free to proceed directly to the next and final step of Qiskit patterns, where we will visualize this information.

# %%
from qiskit_aer.primitives import Estimator

# Create an Estimator object
estimator = Estimator()

# Submit the circuit to Estimator
job = estimator.run([qc] * len(observables), observables)

# Once the job is complete, get the result
job.result()

print(job.result())

# %% [markdown]
# ## Step 4: Post-process the results <a name="step-4"></a>

# %% [markdown]
# The last step of Qiskit patterns is where we process, analyze, and visualize the results of our job.
#
# There are many ways you can choose to do this. We showcase a number of different options throughout the IBM Quantum Challenge. Remember that the goal of this event is to help you understand how to use this workflow to succeed in running your own utility-scale quantum experiments. It's always a great day to learn something new!
#
# Here we are going to collect our data and plot it on a graph we construct.

# %%
import matplotlib.pyplot as plt
import numpy as np

# collect the data
data = ['IZ', 'IX', 'ZI', 'XI', 'ZZ', 'XX']
values = job.result().values

# set up our graph
container = plt.plot(data, values, '-o')

# label each axis
plt.xlabel('Observables')
plt.ylabel('Values')

# draw the final graph
plt.show()

# %% [markdown]
# You *should* see the two-qubit operators (`ZZ` and `XX`) have a value that's close to 1, and the one-qubit operators have a value that's close to 0. This shows that your circuit is entangled. Great work.
#
# The plot displays as a line graph, but really it would be better to visualize this as a bar graph. That brings us to our next exercise.

# %% [markdown]
# ### Exercise 2 <a name="ex-2"></a>
# <div class="alert alert-block alert-success">
#
# The IBM Quantum Challenge frequently asks you to do some independent research or dive into the documentation on your own.
#
# As we said earlier, the goal is for you to understand how to use this workflow to succeed in running your own utility-scale quantum experiments. If you're a programmer, you probably already know the truth: half of your job is looking up the documentation for a method whose parameters you no longer remember, or researching a function you've never used before.
#
# The good news is IBM has spent an enormous amount of time building, updating, and polishing the documentation for Qiskit 1.x, so you will be able to use it throughout the full event.
#
# However, you need to be ready for any documentation. For this exercise, you will need the documentation for `matplotlib`.
#
# **Your task is to convert the line plot above into a bar graph.**
#
# Easy Mode: [click here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html)
#
# Hard Mode: [click here](https://matplotlib.org/stable/)
#
# Hint: *The data is the same, the axis labels are the same, and the draw method is the same. You only need to modify one line of code, the one about setting up your graph. Remember we have matplotlib imported as the variable* `plt`
# </div>

# %%
# collect the data
data = ['IZ', 'IX', 'ZI', 'XI', 'ZZ', 'XX']
values = job.result().values

### The code you write should NOT change the
### variable name `container`

## Write your code below here ##




## Don't change any code past this line, but remember to run the cell.

# label each axis
plt.xlabel('Observables')
plt.ylabel('Values')

# draw the final graph
plt.show()

# %%
# Submit your answer using following code

from qc_grader.challenges.iqc_2024 import grade_lab0_ex2

grade_lab0_ex2(container, job)

# %% [markdown]
# # Congratulations! <a name="congrats"></a>
#
# Congratulations on making it to the end of lab 0!
#
# You learned how to follow the workflow of Qiskit patterns to set up, optimize, run, and process your circuit. You successfully created a two-qubit Bell state, and showed that it was properly entangled by visualizing the operators. You used documentation to help figure out how to improve your code, and you (hopefully) passed every exercise. Rock on!
#
# WIth the basics down, you’re now ready to begin thinking like a quantum developer. It’s a little different than thinking like a quantum physicist, though. We’re not just making discoveries about how the world works—we’re trying to use quantum mechanics as a tool to solve meaningful problems and enact positive change in the world.
#
# We like to say we’ve entered the era of quantum utility—for the first time, quantum computers can do things beyond the abilities of brute-force classical computing. Now, we’re looking for quantum advantage, where quantum computers are the best way to solve the problem. We need you, the quantum community for that—we need to uncover and implement quantum algorithms and apply them to real-world use cases. The rest of the challenge will be devoted to that—getting you to start thinking like a quantum developer.
#
# And of course, solving problems with real-world impact means thinking about who you’re impacting and how. At IBM we hold that we must research and develop technology responsibly. To that end, quantum computing and ethics experts at IBM have been researching the societal implications of quantum computing, and our role as a quantum computing provider in mitigating potentially undesired consequences of the technology. We encourage you to learn more by reading about our [Responsible Quantum Computing](https://www.ibm.com/quantum/blog/responsible-quantum) effort.
#
# You are now ready to move forward with the rest of the [IBM Quantum Challenge](https://challenges.quantum.ibm.com/2024). Good luck!

# %% [markdown]
# ## Additional information
#
# **Created by:** Brian Ingmanson
#
# **Advised by:** Junye Huang
#
# **Version:** 1.0

# %% [markdown]
# ## Qiskit packages versions

# %%
import qiskit
import qiskit_ibm_runtime

print(f'Qiskit: {qiskit.__version__}')
print(f'Qiskit IBM Runtime: {qiskit_ibm_runtime.__version__}')
